# %%
from selenium import webdriver
import time
from tqdm import tqdm
import numpy as np
import pandas as pd
import re
import os

# %%
driver = webdriver.Edge()

# %%
url = 'https://desibazaar.pl/en/13-foods-grocery'

# %%
driver.get(url)

# %%
product_sel = 'div.item-product.product_per_4.col-xs-12.col-sm-6.col-md-6.col-lg-4.col-xl-3'
prod_image_sel = '.first-image'
prod_flag_sel = 'ul.product-flag'
prod_name_sel = 'div.product_desc h3 a.product_name'
prod_price_sel = 'div.product_desc span.price'

# %%
DATA = []

# %%
def collect_data():
    for i in tqdm(range(34), total=34, desc='Processing...', colour='green'):
        products = driver.find_elements(by='css selector', value=product_sel)

        for product in products:
            try:
                prod_image_url = product.find_element(by='css selector', value=prod_image_sel).get_attribute("src")
            except:
                prod_image_url = np.nan
            try:
                prod_flag = product.find_element(by='css selector', value=prod_flag_sel).text
            except:
                prod_flag = np.nan
            try:
                prod_name = product.find_element(by='css selector', value=prod_name_sel).text
            except: 
                prod_name = np.nan
            try:
                prod_price = product.find_element(by='css selector', value=prod_price_sel).text
            except:
                prod_price = np.nan

            data = {
                'prod_image_url': prod_image_url,
                'prod_flag':  prod_flag,
                'prod_name': prod_name,
                'prod_price': prod_price
            }

            DATA.append(data)

        next_btn = driver.find_element(by='css selector', value='#js-product-list > nav > ul > li:nth-child(6) > a')
        next_btn.click()
        time.sleep(3)

# %%
collect_data()
# Out:
# Processing...: 100%|███████████████████████████████████████████████████████████████████| 34/34 [04:07<00:00,  7.29s/it]

# %%
desi_data = pd.DataFrame.from_dict(DATA)

# %%
desi_data.rename(columns={
    'prod_image_url': 'PROD_IMAGE_URL',
    'prod_flag': 'PROD_FLAG',
    'prod_name': 'PROD_NAME',
    'prod_price': 'PROD_PRICE'
}, inplace=True)

# %%
desi_data['STORE_ID'] = 156
desi_data['STORE_NAME'] = 'Desi Bazar Lebensmittelmarkt (Bangladeshi, Indian and Asian Groceries)'
desi_data['TEAM_MEMBER'] = 'Faromika Ifeoluwa'

# %%
desi_data.to_csv('desi_bazaar.csv', index=False)

# %% [markdown]
# ### Second Website

# %%
categories = [
    'Lentil, Beans & Pulses',
    'Ready Meals & Mixes',
    'Frozen Foods',
    'Masala & Spices',
    'Dry Fruits & Nuts',
    'Chilled Foods',
    'Seeds & Grains',
    'Tin Foods',
    'Drinks & Beverages',
    'Powa & Mamra',
    'Sweets, Snacks & Savouries',
    'Pani Puri & Papads',
    'Oils & Ghee',
    'Jaggery & Sugars',
    'Instant Mixes',
    'Food Colours & Flavours',
    'Noodles & Vermicelli',
    'Cooking Salts & Powders'
]

# %%
def collect_data_by_cat(category):
    DATA = []
    category = re.sub(r'[,\s+&]', '-', category).lower()
    category = re.sub(r'-+', '-', category).lower()
    url = f"https://bazaar-foods.co.uk/collections/{category}"
#     https://bazaar-foods.co.uk/collections/lentil-beans-pulses
#     print(url)
    driver = webdriver.Edge()
    driver.get(url)
    
    time.sleep(4)
    
    prod_blocks = driver.find_elements(by='css selector', value='div.product-block__inner')
    
    for prod in tqdm(prod_blocks, colour='green'):
        
#         prod_opt_btn = prod.find_element(by='css selector', value='#collection > div > div.product-list-container.product-list-container--sidebar.cc-animate-init.-in.cc-animate-complete > div.product-list.product-grid.row.grid.use-infinite-scroll > div:nth-child(1) > div > div.product-form > a')
#         prod_opt_btn.click()
        img_url_sel = 'div.inner > a'
        prod_name_sel = '.product-block__title-price'
#         prod_desc_sel = '.product-description.product-hide-mobile.rte.product-detail__gap-lg'
        price_sel = 'span.amount.theme-money'
#         prod_link_sel = '.quick-buy.btn'
        
        img_url = prod.find_element(by='css selector', value=img_url_sel).get_attribute("href")
        prod_name = prod.find_element(by='css selector', value=prod_name_sel).text
        price = prod.find_element(by='css selector', value=price_sel).text
#         prod_link = prod.find_element(by='css selector', value=prod_link_sel).get_attribute("href")
        
        data = {
            'img_url': img_url,
            'prod_name': prod_name,
            'price': price
        }
        
        DATA.append(data)
    df = pd.DataFrame.from_dict(DATA)
    df['category'] = category
    df.to_csv(os.path.join('DESI_BAZAAR_2', f"{category.replace('-', '_')}.csv"), index=False)
    print('Done.......')
    return DATA

# %%
DATA = collect_data_by_cat(categories[0])
# Out:
# https://bazaar-foods.co.uk/collections/lentil-beans-pulses
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  8.12it/s]

# %%
DATA
# Out:
# [{'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-toor-dall-plain',
#   'prod_name': 'Heera Toor Dall Plain\nFrom £2.19',
#   'price': '£2.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-moong-dall-washed',
#   'prod_name': 'Heera Moong Dall Washed\nFrom £1.85 £5.69',
#   'price': '£1.85'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-chana-dall',
#   'prod_name': 'Heera Chana Dall\nFrom £1.59',
#   'price': '£1.59'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-moong-whole-beans',
#   'prod_name': 'East End Moong Whole Beans\nFrom £1.69',
#   'price': '£1.69'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/udaya-toor-dall',
#   'prod_name': 'Udaya Toor Dall\nFrom £3.19',
#   'price': '£3.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-chick-peas',
#   'prod_name': 'Heera Chick Peas\nFrom £1.75',
#   'price': '£1.75'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-urid-dall-washed',
#   'prod_name': 'East End Urid Dall Washed\nFrom £2.19',
#   'price': '£2.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-moong-dall-washed',
#   'prod_name': 'East End Moong Dall Washed\nFrom £3.39',
#   'price': '£3.39'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-black-eye-beans',
#   'prod_name': 'East End Black Eye Beans\nFrom £1.89',
#   'price': '£1.89'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/udaya-roasted-gram-split',
#   'prod_name': 'Udaya Roasted Gram Split\nFrom £1.69',
#   'price': '£1.69'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-urid-dall-washed',
#   'prod_name': 'Heera Urid Dall Washed\nFrom £1.99 £5.99',
#   'price': '£1.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-toor-dall-dry',
#   'prod_name': 'East End Toor Dall Dry\nFrom £3.29',
#   'price': '£3.29'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-kala-chana',
#   'prod_name': 'Heera Kala Chana\nFrom £1.59',
#   'price': '£1.59'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-chick-peas',
#   'prod_name': 'East End Chick Peas\nFrom £1.99',
#   'price': '£1.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/udaya-urid-gota-1kg',
#   'prod_name': 'Udaya Urid Gota\nFrom £3.19',
#   'price': '£3.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-moong-whole',
#   'prod_name': 'Heera Moong Whole\nFrom £1.79 £5.49',
#   'price': '£1.79'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-moong-dall-chilka',
#   'prod_name': 'Heera Moong Dall Chilka\nFrom £1.59',
#   'price': '£1.59'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-chana-dal-2kg',
#   'prod_name': 'Natco Chana Dal\nFrom £1.39',
#   'price': '£1.39'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-soya-chunks',
#   'prod_name': 'Heera Soya Chunks\nFrom £1.95',
#   'price': '£1.95'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-urid-whole',
#   'prod_name': 'East End Urid Whole\nFrom £1.59',
#   'price': '£1.59'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-red-split-lentils',
#   'prod_name': 'East End Red Split Lentils\nFrom £3.19',
#   'price': '£3.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/kashi-toor-dal-1-5kg',
#   'prod_name': 'Kashi Toor Dal - 1.5kg\n£3.99',
#   'price': '£3.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-red-split-lentils',
#   'prod_name': 'Natco Red Split Lentils\nFrom £1.39',
#   'price': '£1.39'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-phool-makhana-100g',
#   'prod_name': 'Natco Phool Makhana - 100g\nFrom £2.99',
#   'price': '£2.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-red-split-lentils',
#   'prod_name': 'Heera Red Split Lentils\nFrom £2.99',
#   'price': '£2.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-red-kidney-beans',
#   'prod_name': 'Heera Red Kidney Beans\nFrom £1.99',
#   'price': '£1.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-rose-coco-beans',
#   'prod_name': 'East End Rose Coco Beans\nFrom £2.39',
#   'price': '£2.39'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-brown-lentils',
#   'prod_name': 'Natco Brown Lentils\nFrom £1.19',
#   'price': '£1.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-soya-chunks-400g',
#   'prod_name': 'East End Soya Chunks - 400g\n£2.39',
#   'price': '£2.39'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-mung-dal-yellow',
#   'prod_name': 'Natco Mung Dal Yellow\nFrom £3.29',
#   'price': '£3.29'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/uphaar-roasted-chickpeas-split-daria-1kg',
#   'prod_name': 'Uphaar Roasted Chickpeas Split/Daria - 1kg\n£3.49',
#   'price': '£3.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-urid-whole-black',
#   'prod_name': 'Heera Urid Whole Black\nFrom £1.95',
#   'price': '£1.95'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-toor-dal-plain-2kg',
#   'prod_name': 'Natco Toor Dal Plain - 2kg\n£5.49',
#   'price': '£5.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-moth-whole',
#   'prod_name': 'Heera Moth Whole\nFrom £1.75',
#   'price': '£1.75'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/top-op-green-peas-whole-500g',
#   'prod_name': 'Top Op Green Peas Whole - 500g\n£1.15',
#   'price': '£1.15'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-mung-split-chilka-2kg',
#   'prod_name': 'Natco Mung Split (Chilka)\nFrom £1.59',
#   'price': '£1.59'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-dark-red-kidney-beans',
#   'prod_name': 'East End Dark Red Kidney Beans\nFrom £3.49',
#   'price': '£3.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-chana-dall',
#   'prod_name': 'East End Chana Dall\nFrom £2.75',
#   'price': '£2.75'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-yellow-gram-kala-chana',
#   'prod_name': 'East End Yellow Gram / Kala Chana\nFrom £1.45',
#   'price': '£1.45'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/east-end-desi-red-kidney-beans-2kg',
#   'prod_name': 'East End Desi Red Kidney Beans - 2kg\n£4.99',
#   'price': '£4.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-whole-yellow-peas-2kg',
#   'prod_name': 'Natco Whole Yellow Peas\nFrom £0.89',
#   'price': '£0.89'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-black-eye-beans',
#   'prod_name': 'Natco Black Eye Beans\nFrom £1.69',
#   'price': '£1.69'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-brown-lentils',
#   'prod_name': 'Heera Brown Lentils\nFrom £1.49',
#   'price': '£1.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-urid-dall-chilka',
#   'prod_name': 'Heera Urid Dall Chilka\nFrom £1.85',
#   'price': '£1.85'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/top-op-yellow-peas-whole',
#   'prod_name': 'Top Op Yellow Peas Whole\nFrom £1.19',
#   'price': '£1.19'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/kashi-yellow-moong-dal',
#   'prod_name': 'Kashi Yellow Moong Dal\nFrom £1.49',
#   'price': '£1.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/trs-toor-dall-plain-2kg',
#   'prod_name': 'TRS Toor Dall Plain - 2kg\n£5.29',
#   'price': '£5.29'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/natco-kala-chana-brown-chick-peas-2kg',
#   'prod_name': 'Natco Kala Chana (Brown Chick Peas) - 2kg\n£3.99',
#   'price': '£3.99'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/sanam-urid-gota-2kg',
#   'prod_name': 'Sanam Urid Gota - 2kg\n£5.49',
#   'price': '£5.49'},
#  {'img_url': 'https://bazaar-foods.co.uk/collections/lentil-beans-pulses/products/heera-jumbo-chick-peas-2kg',
#   'prod_name': 'Heera Jumbo Chick Peas - 2kg\n£6.99',
#   'price': '£6.99'}]

# %%
os.makedirs('DESI_BAZAAR_2')

# %%
df = pd.DataFrame.from_dict(DATA)
df['category'] = 'Lentils, Beans & Pulses'

# %%
# df

# %%
df.to_csv(os.path.join('DESI_BAZAAR_2', 'lentils_beans_pulses.csv'), index=False)

# %%
for category in categories[8:]:
    collect_data_by_cat(category)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.09it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:01<00:00, 14.83it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  7.59it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:03<00:00, 13.82it/s]
# Done.......
# 0it [00:00, ?it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:01<00:00, 12.91it/s]
# Done.......
# 0it [00:00, ?it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 16.40it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:01<00:00, 13.33it/s]
# Done.......
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:01<00:00, 15.08it/s]
# Done.......

# %%
df
# Out:
#                                               img_url  \
# 0   https://bazaar-foods.co.uk/collections/lentil-...
# 1   https://bazaar-foods.co.uk/collections/lentil-...
# 2   https://bazaar-foods.co.uk/collections/lentil-...
# 3   https://bazaar-foods.co.uk/collections/lentil-...
# 4   https://bazaar-foods.co.uk/collections/lentil-...
# 5   https://bazaar-foods.co.uk/collections/lentil-...
# 6   https://bazaar-foods.co.uk/collections/lentil-...
# 7   https://bazaar-foods.co.uk/collections/lentil-...
# 8   https://bazaar-foods.co.uk/collections/lentil-...
# 9   https://bazaar-foods.co.uk/collections/lentil-...
# 10  https://bazaar-foods.co.uk/collections/lentil-...
# 11  https://bazaar-foods.co.uk/collections/lentil-...
# 12  https://bazaar-foods.co.uk/collections/lentil-...
# 13  https://bazaar-foods.co.uk/collections/lentil-...
# 14  https://bazaar-foods.co.uk/collections/lentil-...
# 15  https://bazaar-foods.co.uk/collections/lentil-...
# 16  https://bazaar-foods.co.uk/collections/lentil-...
# 17  https://bazaar-foods.co.uk/collections/lentil-...
# 18  https://bazaar-foods.co.uk/collections/lentil-...
# 19  https://bazaar-foods.co.uk/collections/lentil-...
# 20  https://bazaar-foods.co.uk/collections/lentil-...
# 21  https://bazaar-foods.co.uk/collections/lentil-...
# 22  https://bazaar-foods.co.uk/collections/lentil-...
# 23  https://bazaar-foods.co.uk/collections/lentil-...
# 24  https://bazaar-foods.co.uk/collections/lentil-...
# 25  https://bazaar-foods.co.uk/collections/lentil-...
# 26  https://bazaar-foods.co.uk/collections/lentil-...
# 27  https://bazaar-foods.co.uk/collections/lentil-...
# 28  https://bazaar-foods.co.uk/collections/lentil-...
# 29  https://bazaar-foods.co.uk/collections/lentil-...
# 30  https://bazaar-foods.co.uk/collections/lentil-...
# 31  https://bazaar-foods.co.uk/collections/lentil-...
# 32  https://bazaar-foods.co.uk/collections/lentil-...
# 33  https://bazaar-foods.co.uk/collections/lentil-...
# 34  https://bazaar-foods.co.uk/collections/lentil-...
# 35  https://bazaar-foods.co.uk/collections/lentil-...
# 36  https://bazaar-foods.co.uk/collections/lentil-...
# 37  https://bazaar-foods.co.uk/collections/lentil-...
# 38  https://bazaar-foods.co.uk/collections/lentil-...
# 39  https://bazaar-foods.co.uk/collections/lentil-...
# 40  https://bazaar-foods.co.uk/collections/lentil-...
# 41  https://bazaar-foods.co.uk/collections/lentil-...
# 42  https://bazaar-foods.co.uk/collections/lentil-...
# 43  https://bazaar-foods.co.uk/collections/lentil-...
# 44  https://bazaar-foods.co.uk/collections/lentil-...
# 45  https://bazaar-foods.co.uk/collections/lentil-...
# 46  https://bazaar-foods.co.uk/collections/lentil-...
# 47  https://bazaar-foods.co.uk/collections/lentil-...
# 48  https://bazaar-foods.co.uk/collections/lentil-...
# 49  https://bazaar-foods.co.uk/collections/lentil-...
#
#                                             prod_name  price  \
# 0                   Heera Toor Dall Plain\nFrom £2.19  £2.19
# 1           Heera Moong Dall Washed\nFrom £1.85 £5.69  £1.85
# 2                        Heera Chana Dall\nFrom £1.59  £1.59
# 3              East End Moong Whole Beans\nFrom £1.69  £1.69
# 4                         Udaya Toor Dall\nFrom £3.19  £3.19
# 5                        Heera Chick Peas\nFrom £1.75  £1.75
# 6               East End Urid Dall Washed\nFrom £2.19  £2.19
# 7              East End Moong Dall Washed\nFrom £3.39  £3.39
# 8                East End Black Eye Beans\nFrom £1.89  £1.89
# 9                Udaya Roasted Gram Split\nFrom £1.69  £1.69
# 10           Heera Urid Dall Washed\nFrom £1.99 £5.99  £1.99
# 11                 East End Toor Dall Dry\nFrom £3.29  £3.29
# 12                       Heera Kala Chana\nFrom £1.59  £1.59
# 13                    East End Chick Peas\nFrom £1.99  £1.99
# 14                        Udaya Urid Gota\nFrom £3.19  £3.19
# 15                Heera Moong Whole\nFrom £1.79 £5.49  £1.79
# 16                Heera Moong Dall Chilka\nFrom £1.59  £1.59
# 17                        Natco Chana Dal\nFrom £1.39  £1.39
# 18                      Heera Soya Chunks\nFrom £1.95  £1.95
# 19                    East End Urid Whole\nFrom £1.59  £1.59
# 20             East End Red Split Lentils\nFrom £3.19  £3.19
# 21                      Kashi Toor Dal - 1.5kg\n£3.99  £3.99
# 22                Natco Red Split Lentils\nFrom £1.39  £1.39
# 23             Natco Phool Makhana - 100g\nFrom £2.99  £2.99
# 24                Heera Red Split Lentils\nFrom £2.99  £2.99
# 25                 Heera Red Kidney Beans\nFrom £1.99  £1.99
# 26               East End Rose Coco Beans\nFrom £2.39  £2.39
# 27                    Natco Brown Lentils\nFrom £1.19  £1.19
# 28                 East End Soya Chunks - 400g\n£2.39  £2.39
# 29                  Natco Mung Dal Yellow\nFrom £3.29  £3.29
# 30  Uphaar Roasted Chickpeas Split/Daria - 1kg\n£3.49  £3.49
# 31                 Heera Urid Whole Black\nFrom £1.95  £1.95
# 32                  Natco Toor Dal Plain - 2kg\n£5.49  £5.49
# 33                       Heera Moth Whole\nFrom £1.75  £1.75
# 34              Top Op Green Peas Whole - 500g\n£1.15  £1.15
# 35              Natco Mung Split (Chilka)\nFrom £1.59  £1.59
# 36         East End Dark Red Kidney Beans\nFrom £3.49  £3.49
# 37                    East End Chana Dall\nFrom £2.75  £2.75
# 38      East End Yellow Gram / Kala Chana\nFrom £1.45  £1.45
# 39        East End Desi Red Kidney Beans - 2kg\n£4.99  £4.99
# 40                Natco Whole Yellow Peas\nFrom £0.89  £0.89
# 41                  Natco Black Eye Beans\nFrom £1.69  £1.69
# 42                    Heera Brown Lentils\nFrom £1.49  £1.49
# 43                 Heera Urid Dall Chilka\nFrom £1.85  £1.85
# 44               Top Op Yellow Peas Whole\nFrom £1.19  £1.19
# 45                 Kashi Yellow Moong Dal\nFrom £1.49  £1.49
# 46                   TRS Toor Dall Plain - 2kg\n£5.29  £5.29
# 47   Natco Kala Chana (Brown Chick Peas) - 2kg\n£3.99  £3.99
# 48                       Sanam Urid Gota - 2kg\n£5.49  £5.49
# 49                Heera Jumbo Chick Peas - 2kg\n£6.99  £6.99
#
#                    category
# 0   Lentils, Beans & Pulses
# 1   Lentils, Beans & Pulses
# 2   Lentils, Beans & Pulses
# 3   Lentils, Beans & Pulses
# 4   Lentils, Beans & Pulses
# 5   Lentils, Beans & Pulses
# 6   Lentils, Beans & Pulses
# 7   Lentils, Beans & Pulses
# 8   Lentils, Beans & Pulses
# 9   Lentils, Beans & Pulses
# 10  Lentils, Beans & Pulses
# 11  Lentils, Beans & Pulses
# 12  Lentils, Beans & Pulses
# 13  Lentils, Beans & Pulses
# 14  Lentils, Beans & Pulses
# 15  Lentils, Beans & Pulses
# 16  Lentils, Beans & Pulses
# 17  Lentils, Beans & Pulses
# 18  Lentils, Beans & Pulses
# 19  Lentils, Beans & Pulses
# 20  Lentils, Beans & Pulses
# 21  Lentils, Beans & Pulses
# 22  Lentils, Beans & Pulses
# 23  Lentils, Beans & Pulses
# 24  Lentils, Beans & Pulses
# 25  Lentils, Beans & Pulses
# 26  Lentils, Beans & Pulses
# 27  Lentils, Beans & Pulses
# 28  Lentils, Beans & Pulses
# 29  Lentils, Beans & Pulses
# 30  Lentils, Beans & Pulses
# 31  Lentils, Beans & Pulses
# 32  Lentils, Beans & Pulses
# 33  Lentils, Beans & Pulses
# 34  Lentils, Beans & Pulses
# 35  Lentils, Beans & Pulses
# 36  Lentils, Beans & Pulses
# 37  Lentils, Beans & Pulses
# 38  Lentils, Beans & Pulses
# 39  Lentils, Beans & Pulses
# 40  Lentils, Beans & Pulses
# 41  Lentils, Beans & Pulses
# 42  Lentils, Beans & Pulses
# 43  Lentils, Beans & Pulses
# 44  Lentils, Beans & Pulses
# 45  Lentils, Beans & Pulses
# 46  Lentils, Beans & Pulses
# 47  Lentils, Beans & Pulses
# 48  Lentils, Beans & Pulses
# 49  Lentils, Beans & Pulses

# %%
df_combined = pd.DataFrame()

# %%
for file in os.listdir('DESI_BAZAAR_2'):
    df = pd.read_csv(os.path.join('DESI_BAZAAR_2', file))
    df_combined = pd.concat([df_combined, df], axis=0, ignore_index=True)

# %%
df_combined.shape
# Out:
# (595, 4)

# %%
df_combined.isna().sum()
# Out:
# img_url      0
# prod_name    0
# price        0
# category     0
# dtype: int64

# %%
df_combined.rename(
    columns={
        'img_url': 'PROD_IMAGE_URL',
        'prod_name': 'PROD_NAME',
        'price': 'PROD_PRICE',
        'category': 'PROD_CATEGORY'
    },
    inplace=True
)

# %%
df_combined['STORE_NAME'] = 'Desi Bazar Lebensmittelmarkt (Bangladeshi, Indian and Asian Groceries)'
df_combined['STORE_ID'] = 280
df_combined['TEAM_MEMBER'] = 'Faromika Ifeoluwa'

# %%
df_combined.to_csv('desi_bazaar_2.csv')
